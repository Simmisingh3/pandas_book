# %%
import pandas as pd

# %%
pip install MySQL-Connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as connection

# %%
df = pd.read_excel("Online Retail.xlsx")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df["Country"]
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 541909, dtype: object

# %%
type(df["Country"])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df[["UnitPrice"]]
# Out:
#         UnitPrice
# 0            2.55
# 1            3.39
# 2            2.75
# 3            3.39
# 4            3.39
# ...           ...
# 541904       0.85
# 541905       2.10
# 541906       4.15
# 541907       4.15
# 541908       4.95
#
# [541909 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df[['UnitPrice','Country']]
# Out:
#         UnitPrice         Country
# 0            2.55  United Kingdom
# 1            3.39  United Kingdom
# 2            2.75  United Kingdom
# 3            3.39  United Kingdom
# 4            3.39  United Kingdom
# ...           ...             ...
# 541904       0.85          France
# 541905       2.10          France
# 541906       4.15          France
# 541907       4.15          France
# 541908       4.95          France
#
# [541909 rows x 2 columns]

# %%
type(df[['UnitPrice','Country']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Description','InvoiceNo','CustomerID']]
# Out:
#                                 Description InvoiceNo  CustomerID
# 0        WHITE HANGING HEART T-LIGHT HOLDER    536365     17850.0
# 1                       WHITE METAL LANTERN    536365     17850.0
# 2            CREAM CUPID HEARTS COAT HANGER    536365     17850.0
# 3       KNITTED UNION FLAG HOT WATER BOTTLE    536365     17850.0
# 4            RED WOOLLY HOTTIE WHITE HEART.    536365     17850.0
# ...                                     ...       ...         ...
# 541904          PACK OF 20 SPACEBOY NAPKINS    581587     12680.0
# 541905         CHILDREN'S APRON DOLLY GIRL     581587     12680.0
# 541906        CHILDRENS CUTLERY DOLLY GIRL     581587     12680.0
# 541907      CHILDRENS CUTLERY CIRCUS PARADE    581587     12680.0
# 541908        BAKING SET 9 PIECE RETROSPOT     581587     12680.0
#
# [541909 rows x 3 columns]

# %%
df.dtypes=='O'
# Out:
# InvoiceNo       True
# StockCode       True
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# Country         True
# dtype: bool

# %%
df.dtypes=='object'
# Out:
# InvoiceNo       True
# StockCode       True
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# Country         True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# InvoiceNo      object
# StockCode      object
# Description    object
# Country        object
# dtype: object

# %%
df.dtypes[df.dtypes=="O"].index # Showing the column name of the object data
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Country'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="O"].index]  #showing the whole data having objects
# Out:
#        InvoiceNo StockCode                          Description  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1         536365     71053                  WHITE METAL LANTERN
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...          ...       ...                                  ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#                Country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
# ...                ...
# 541904          France
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#         InvoiceNo StockCode                         Description  \
# count      541909    541909                              540455
# unique      25900      4070                                4223
# top        573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq         1114      2313                                2369
#
#                Country
# count           541909
# unique              38
# top     United Kingdom
# freq            495478

# %%
df.dtypes[df.dtypes=="float"]
# Out:
# UnitPrice     float64
# CustomerID    float64
# dtype: object

# %%
df.dtypes[df.dtypes=="float"].index
# Out:
# Index(['UnitPrice', 'CustomerID'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="float"].index]
# Out:
#         UnitPrice  CustomerID
# 0            2.55     17850.0
# 1            3.39     17850.0
# 2            2.75     17850.0
# 3            3.39     17850.0
# 4            3.39     17850.0
# ...           ...         ...
# 541904       0.85     12680.0
# 541905       2.10     12680.0
# 541906       4.15     12680.0
# 541907       4.15     12680.0
# 541908       4.95     12680.0
#
# [541909 rows x 2 columns]

# %%
df.InvoiceNo
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 541909, dtype: object

# %%
df["InvoiceNo"]
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 541909, dtype: object

# %%
df['InvoiceNo'][1:40:5] # Getting InvoiceNo data from 1 to 40 with a gap of 5
# Out:
# 1     536365
# 6     536365
# 11    536367
# 16    536367
# 21    536368
# 26    536370
# 31    536370
# 36    536370
# Name: InvoiceNo, dtype: object

# %%
df["Description"]
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
df["Description"]="simmi" # Overwrites the description to Simmi, Although its temporary

# %%
df
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 0         536365    85123A       simmi         6 2010-12-01 08:26:00
# 1         536365     71053       simmi         6 2010-12-01 08:26:00
# 2         536365    84406B       simmi         8 2010-12-01 08:26:00
# 3         536365    84029G       simmi         6 2010-12-01 08:26:00
# 4         536365    84029E       simmi         6 2010-12-01 08:26:00
# ...          ...       ...         ...       ...                 ...
# 541904    581587     22613       simmi        12 2011-12-09 12:50:00
# 541905    581587     22899       simmi         6 2011-12-09 12:50:00
# 541906    581587     23254       simmi         4 2011-12-09 12:50:00
# 541907    581587     23255       simmi         4 2011-12-09 12:50:00
# 541908    581587     22138       simmi         3 2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# ...

# %%
df["CustomerID"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: CustomerID, Length: 541909, dtype: bool

# %%
df["CustomerID"].isnull().sum()
# Out:
# 135080

# %%
df[df["CustomerID"].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139       simmi        56 2010-12-01 11:52:00
# 1443      536544     21773       simmi         1 2010-12-01 14:32:00
# 1444      536544     21774       simmi         2 2010-12-01 14:32:00
# 1445      536544     21786       simmi         4 2010-12-01 14:32:00
# 1446      536544     21787       simmi         2 2010-12-01 14:32:00
# ...          ...       ...         ...       ...                 ...
# 541536    581498    85099B       simmi         5 2011-12-09 10:26:00
# 541537    581498    85099C       simmi         4 2011-12-09 10:26:00
# 541538    581498     85150       simmi         1 2011-12-09 10:26:00
# 541539    581498     85174       simmi         1 2011-12-09 10:26:00
# 541540    581498       DOT       simmi         1 2011-12-09 10:26:00
#
#         UnitPrice  CustomerID         Country
# 622          0.00         NaN  United Kingdom
# ...

# %%
df1=pd.read_csv("pollution.csv")

# %%
df1
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  \
# 0          1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79
# 1          2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92
# 2          3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71
# 3          4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84
# 4          5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97
# ...      ...   ...    ...  ...   ...    ...   ...   ...     ...  ...     ...
# 43819  43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97
# 43820  43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78
# 43821  43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70
# 43822  43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72
# 43823  43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85
#
#        Is  Ir
# 0       0   0
# ...

# %%
df1.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'pm2.5', 'DEWP', 'TEMP', 'PRES',
#        'cbwd', 'Iws', 'Is', 'Ir'],
#       dtype='object')

# %%
df1['day'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43819    False
# 43820    False
# 43821    False
# 43822    False
# 43823    False
# Name: day, Length: 43824, dtype: bool

# %%
df=pd.read_excel("Online Retail.xlsx")

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df["UnitPrice"]
# Out:
# 0         2.55
# 1         3.39
# 2         2.75
# 3         3.39
# 4         3.39
#           ...
# 541904    0.85
# 541905    2.10
# 541906    4.15
# 541907    4.15
# 541908    4.95
# Name: UnitPrice, Length: 541909, dtype: float64

# %%
df["UnitPrice"]==max(df["UnitPrice"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: UnitPrice, Length: 541909, dtype: bool

# %%
df[df["UnitPrice"]==max(df["UnitPrice"])]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 222681   C556445         M      Manual        -1 2011-06-10 15:31:00
#
#         UnitPrice  CustomerID         Country
# 222681    38970.0     15098.0  United Kingdom

# %%
df[df["UnitPrice"] == max(df["UnitPrice"])]["Country"]
# Out:
# 222681    United Kingdom
# Name: Country, dtype: object

# %%
df["Country"]
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 541909, dtype: object

# %%
df["Country"].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df["Country"]=="France"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904     True
# 541905     True
# 541906     True
# 541907     True
# 541908     True
# Name: Country, Length: 541909, dtype: bool

# %%
df[df["Country"]=="France"]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# ...

# %%
len(df[df["Country"]=="France"])
# Out:
# 8557

# %% [markdown]
# ## Greater Than Less Than

# %%
df["Quantity"]
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 541909, dtype: int64

# %%
df[df["Quantity"]>32]  # List showing quantity greater than 32
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 31        536370     10002        INFLATABLE POLITICAL GLOBE         48
# 44        536370     22492            MINI PAINT SET VINTAGE         36
# 46        536371     22086    PAPER CHAIN KIT 50'S CHRISTMAS         80
# 82        536376     22114  HOT WATER BOTTLE TEA AND SYMPATHY        48
# 83        536376     21733   RED HANGING HEART T-LIGHT HOLDER        64
# ...          ...       ...                                ...       ...
# 541835    581579     23581             JUMBO BAG PAISLEY PARK        40
# 541865    581583     20725            LUNCH BAG RED RETROSPOT        40
# 541866    581583     85038    6 CHOCOLATE LOVE HEART T-LIGHTS        36
# 541867    581584     20832   RED FLOCK LOVE HEART PHOTO FRAME        72
# 541868    581584     85038    6 CHOCOLATE LOVE HEART T-LIGHTS        48
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df["Quantity"]>32]["Country"]
# Out:
# 31                France
# 44                France
# 46        United Kingdom
# 82        United Kingdom
# 83        United Kingdom
#                ...
# 541835    United Kingdom
# 541865    United Kingdom
# 541866    United Kingdom
# 541867    United Kingdom
# 541868    United Kingdom
# Name: Country, Length: 24757, dtype: object

# %%
sum(df["Country"].duplicated())
# Out:
# 541871

# %%
df[(df["Quantity"]>45) & (df["UnitPrice"]<3.39)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 31        536370     10002          INFLATABLE POLITICAL GLOBE         48
# 46        536371     22086      PAPER CHAIN KIT 50'S CHRISTMAS         80
# 83        536376     21733     RED HANGING HEART T-LIGHT HOLDER        64
# 96        536378     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 101       536378    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA        48
# ...          ...       ...                                  ...       ...
# 541711    581567     21326     AGED GLASS SILVER T-LIGHT HOLDER       144
# 541746    581571     23167       SMALL CERAMIC TOP STORAGE JAR         96
# 541747    581571     21314        SMALL GLASS HEART TRINKET POT        48
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541868    581584     85038      6 CHOCOLATE LOVE HEART T-LIGHTS        48
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
date = pd.to_datetime(df['InvoiceDate'])   # Converting order to date and time

# %%
date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %% [markdown]
# # Date time conversion- Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['InvoiceDate']) 
# created another column name converted_order_date with datetime format

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
# extract just "year" and try to create one more column
df['order_date_year']=df['converted_order_date'].dt.year

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
#extract just ""Month"" and try to create one new column
df['order_date_month']=df['converted_order_date'].dt.month

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
#extract just week and try to create one new column
df['order_date_week']=df['converted_order_date'].dt.week
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5336\4048788248.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week']=df['converted_order_date'].dt.week

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df['order_date_day']=df['converted_order_date'].dt.weekday

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df[['converted_order_date', 'order_date_month','order_date_week','order_date_day']]
# Out:
#        converted_order_date  order_date_month  order_date_week  order_date_day
# 0       2010-12-01 08:26:00                12               48               2
# 1       2010-12-01 08:26:00                12               48               2
# 2       2010-12-01 08:26:00                12               48               2
# 3       2010-12-01 08:26:00                12               48               2
# 4       2010-12-01 08:26:00                12               48               2
# ...                     ...               ...              ...             ...
# 541904  2011-12-09 12:50:00                12               49               4
# 541905  2011-12-09 12:50:00                12               49               4
# 541906  2011-12-09 12:50:00                12               49               4
# 541907  2011-12-09 12:50:00                12               49               4
# 541908  2011-12-09 12:50:00                12               49               4
#
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#   converted_order_date  order_date_year  order_date_month  order_date_week  \
# 0  2010-12-01 08:26:00             2010                12               48
# ...

# %%
#show 2010 data only
df[df['order_date_year']==2010]
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 42476    539991     21618       4 WILDFLOWER BOTANICAL CANDLES         1
# 42477    539991     72741                GRAND CHOCOLATECANDLE         4
# 42478    539992     21470        FLOWER VINE RAFFIA FOOD COVER         1
# 42479    539992     22258              FELT FARM ANIMAL RABBIT         1
# 42480    539992     21155                RED RETROSPOT PEG BAG         1
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
# show name wise months
df['order_date_month_name']=df['converted_order_date'].dt.month_name()

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
# show october data only
df[df['order_date_month']==10]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 370931    569203     79321                   CHILLI LIGHTS        48
# 370932    569203     21154       RED RETROSPOT OVEN GLOVE         20
# 370933    569204     21790              VINTAGE SNAP CARDS         4
# 370934    569204     23284   DOORMAT KEEP CALM AND COME IN        15
# 370935    569204     23355      HOT WATER BOTTLE KEEP CALM         4
# ...          ...       ...                             ...       ...
# 431668    573695     23407  SET OF 2 TRAYS HOME SWEET HOME         2
# 431669    573695     23543             WALL ART KEEP CALM          1
# 431670    573695     23397     FOOT STOOL HOME SWEET HOME          4
# 431671    573726     72817                           check       -67
# 431672    573734     72818                           check       -26
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 370931 2011-10-02 10:32:00       4.95     16353.0  United Kingdom
# ...

# %%
df[df['order_date_month_name']=='October']
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 370931    569203     79321                   CHILLI LIGHTS        48
# 370932    569203     21154       RED RETROSPOT OVEN GLOVE         20
# 370933    569204     21790              VINTAGE SNAP CARDS         4
# 370934    569204     23284   DOORMAT KEEP CALM AND COME IN        15
# 370935    569204     23355      HOT WATER BOTTLE KEEP CALM         4
# ...          ...       ...                             ...       ...
# 431668    573695     23407  SET OF 2 TRAYS HOME SWEET HOME         2
# 431669    573695     23543             WALL ART KEEP CALM          1
# 431670    573695     23397     FOOT STOOL HOME SWEET HOME          4
# 431671    573726     72817                           check       -67
# 431672    573734     72818                           check       -26
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 370931 2011-10-02 10:32:00       4.95     16353.0  United Kingdom
# ...

# %%
df[(df['order_date_month']==10) & (df['order_date_month_name']=='October')]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 370931    569203     79321                   CHILLI LIGHTS        48
# 370932    569203     21154       RED RETROSPOT OVEN GLOVE         20
# 370933    569204     21790              VINTAGE SNAP CARDS         4
# 370934    569204     23284   DOORMAT KEEP CALM AND COME IN        15
# 370935    569204     23355      HOT WATER BOTTLE KEEP CALM         4
# ...          ...       ...                             ...       ...
# 431668    573695     23407  SET OF 2 TRAYS HOME SWEET HOME         2
# 431669    573695     23543             WALL ART KEEP CALM          1
# 431670    573695     23397     FOOT STOOL HOME SWEET HOME          4
# 431671    573726     72817                           check       -67
# 431672    573734     72818                           check       -26
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 370931 2011-10-02 10:32:00       4.95     16353.0  United Kingdom
# ...

# %% [markdown]
# # count

# %%
#find the month with maxumun of something-like maximum sales---no. of times the month has arrived
#(similar to 'group by' function of sql)
#here the 12 month is coming maximum no. of times-means maximum sales
# and 2nd month least times
df['order_date_month'].value_counts()
# Out:
# 11    84711
# 12    68006
# 10    60742
# 9     50226
# 7     39518
# 5     37030
# 6     36874
# 3     36748
# 8     35284
# 1     35147
# 4     29916
# 2     27707
# Name: order_date_month, dtype: int64

# %%
df2 = pd.read_csv("sales_data_final.csv")

# %%
df2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df2.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df2['converted_order_date'] = pd.to_datetime(df2['order_date'])

# %%
df2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df2['order_date_year']=df2['converted_order_date'].dt.year

# %%
df2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df2['order_date_month']=df2['converted_order_date'].dt.month

# %%
df2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_month'].value_counts()
# Out:
# 11    84711
# 12    68006
# 10    60742
# 9     50226
# 7     39518
# 5     37030
# 6     36874
# 3     36748
# 8     35284
# 1     35147
# 4     29916
# 2     27707
# Name: order_date_month, dtype: int64

# %%
df2.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'converted_order_date', 'order_date_year', 'order_date_month'],
#       dtype='object')

# %%
#try to find cost to company
#it will be (discount+shipment cost)=cost to company
df2['cost_to_company']=df2['discount']+df2['shipping_cost']

# %%
df2['cost_to_company']
# Out:
# 0        35.46
# 1         9.82
# 2         8.17
# 3         5.32
# 4         4.80
#          ...
# 51285     1.09
# 51286     0.49
# 51287     0.35
# 51288     0.20
# 51289     0.37
# Name: cost_to_company, Length: 51290, dtype: float64

# %%
#find order where cost to company maximum
df2[df2['cost_to_company']==max(df2['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region  ... quantity discount    profit  \
# 13891  New York  United States     US   East  ...        7      0.0  762.1845
#
#       shipping_cost order_priority  year  converted_order_date  \
# 13891        933.57       Critical  2012            2012-07-31
#
#        order_date_year  order_date_month cost_to_company
# 13891             2012                 7          933.57
#
# [1 rows x 25 columns]

# %%
df2[df2['cost_to_company']==max(df2['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
# deleting a column
df2.drop('cost_to_company',axis=1)
#Axis of row = 0 and axis of column=1. This cost to company is not present in any row, thats why we give axis =1
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df2.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
#to permanantly delete it, !)we can reassign  this entire value to dataframe, value will be overwritten.
#2)else there is a parameter called as inplace

# %%
df2.drop('cost_to_company',axis=1,inplace=True) #deleted it permanantly

# %%
df2
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df2.drop(1) # temporary deletion
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...
